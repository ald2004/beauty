# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import base64
from io import BytesIO
# %matplotlib inline
# %matplotlib notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
with open('test_xzj_head_bin','rb') as fid:
    xzj_bin=fid.read()
    xzj_array=np.frombuffer(xzj_bin,dtype=np.float32).reshape(256,256,3)
    imshow(xzj_array)

# %%
#importing the requests library
import base64
import requests
# %pylab inline 
import json
from io import BytesIO
from tensorflow.keras.preprocessing import image
# defining the api-endpoint
API_ENDPOINT = "http://10.1.202.11:5000/makeup/"
image_path = 'imgs/no_makeup/'
image_path +='xzj_head.jpg'
b64_image = ""
# Encoding the JPG,PNG,etc. image to base64 format
with open(image_path, "rb") as imageFile:
    b64_image = base64.b64encode(imageFile.read())

# data to be sent to api
data = {'IMG_BASE64': b64_image}

# sending post request and saving response as response object
r = requests.post(url=API_ENDPOINT, data=data)

# extracting the response
imshow((image.load_img(BytesIO(base64.b64decode(json.loads(r.text)['predictions']['IMAGE'])))))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tmpstr_bin=b'...'
tmpstr_decode=base64.b64decode(tmpstr_bin)
makeup_bin = b"..."
makeup = image.img_to_array(image.load_img(BytesIO(base64.b64decode(tmpstr_bin))))

# %%
img_b64=b"..."

# %%
makeup = image.img_to_array(image.load_img(BytesIO(base64.b64decode(json.loads(r.text)['IMAGE']))))

# %%
import cv2
img=image.img_to_array(image.load_img('imgs/makeup/ref2_f.jpg'))
img2=img.copy()*1.5

# %%
imshow(img/255)

# %%
imshow(img2/255)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image.save_img('imgs/makeup/ref2_f_whited.jpg',img2)

# %%
f=open('imgs/makeup/ref2_f_whited.jpg','rb')
b64_image = base64.b64encode(f.read())
